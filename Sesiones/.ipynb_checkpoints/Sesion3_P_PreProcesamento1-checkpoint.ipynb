# %% [markdown]
# <center> <h1>Herramientas Computacionales <br></br>para la Investigación Interdisciplinaria Reproducible</h1> </center>
#
# <br></br>
#
# * Profesor:  <a href="http://www.pucp.edu.pe/profesor/jose-manuel-magallanes/" target="_blank">Dr. José Manuel Magallanes, PhD</a> ([jmagallanes@pucp.edu.pe](mailto:jmagallanes@pucp.edu.pe))<br>Profesor del **Departamento de Ciencias Sociales, Pontificia Universidad Católica del Peru**.<br>
# Senior Data Scientist del **eScience Institute** and Visiting Professor at **Evans School of Public Policy and Governance, University of Washington**.<br>
# Fellow Catalyst, **Berkeley Initiative for Transparency in Social Sciences, UC Berkeley**.
#
# ## Sesión 3: Pre Procesamiento de Datos
#
#
# ## Parte A: Data Cleaning en Python

# %% [markdown]
# El pre procesamiento de datos es la parte más tediosa del proceso de investigación.
#
# Esta primera parte delata diversos problemas que se tienen con los datos reales que están en la web, como la que vemos a continuación:

# %%
import IPython
wikiLink="https://en.wikipedia.org/wiki/List_of_freedom_indices" 
iframe = '<iframe src=' + wikiLink + ' width=700 height=350></iframe>'
IPython.display.HTML(iframe)
# Out:
# <iframe src=https://en.wikipedia.org/wiki/List_of_freedom_indices width=700 height=350></iframe>

# %%
# aqui instala: 'lxml' y 'beautifulsoup4'
# es posible que necesites salir y volver a cargar notebook

# %%
# Traigamoslo con Pandas

import pandas as pd

wikiTables=pd.read_html(wikiLink,header=0,flavor='bs4',attrs={'class': 'wikitable sortable',})

# %%
# cuantas tenemos?
len(wikiTables)
# Out:
# 1

# %% [markdown]
# Hasta aquí todo parece bien. Como solo hay uno, lo traigo y comienzo a verificar 'suciedades'.

# %%
DF=wikiTables[0]

#primera mirada
DF
# Out:
#                     Country Freedom in the World 2018[10]  \
# 0                  Abkhazia                   partly free
# 1               Afghanistan                      not free
# 2                   Albania                   partly free
# 3                   Algeria                      not free
# 4                   Andorra                          free
# 5                    Angola                      not free
# 6       Antigua and Barbuda                          free
# 7                 Argentina                          free
# 8                   Armenia                   partly free
# 9                 Australia                          free
# 10                  Austria                          free
# 11               Azerbaijan                      not free
# 12                  Bahamas                          free
# 13                  Bahrain                      not free
# 14               Bangladesh                   partly free
# 15                 Barbados                          free
# 16                  Belarus                      not free
# 17                  Belgium                          free
# 18                   Belize                          free
# 19                    Benin                          free
# 20                   Bhutan                   partly free
# 21                  Bolivia                   partly free
# 22   Bosnia and Herzegovina                   partly free
# 23                 Botswana                          free
# 24                   Brazil                          free
# 25                   Brunei                      not free
# 26                 Bulgaria                          free
# 27             Burkina Faso                   partly free
# 28                    Burma                   partly free
# 29                  Burundi                      not free
# ..                      ...                           ...
# 177                  Sweden                          free
# 178             Switzerland                          free
# 179                   Syria                      not free
# 180                  Taiwan                          free
# 181              Tajikistan                      not free
# 182                Tanzania                   partly free
# 183                Thailand                      not free
# 184                    Togo                   partly free
# 185                   Tonga                          free
# 186            Transnistria                      not free
# 187     Trinidad and Tobago                          free
# 188                 Tunisia                          free
# 189                  Turkey                      not free
# 190            Turkmenistan                      not free
# 191                  Tuvalu                          free
# 192                  Uganda                   partly free
# 193                 Ukraine                   partly free
# 194    United Arab Emirates                      not free
# 195          United Kingdom                          free
# 196           United States                          free
# 197                 Uruguay                          free
# 198              Uzbekistan                      not free
# 199                 Vanuatu                          free
# 200               Venezuela                      not free
# 201                 Vietnam                      not free
# 202               West Bank                      not free
# 203          Western Sahara                      not free
# 204                   Yemen                      not free
# 205                  Zambia                   partly free
# 206                Zimbabwe                      not free
#
#     2018 Index of Economic Freedom[11] 2018 Press Freedom Index[3]  \
# 0                                  NaN                         NaN
# 1                        mostly unfree         difficult situation
# 2                      moderately free         noticeable problems
# 3                            repressed         difficult situation
# 4                                  NaN      satisfactory situation
# 5                            repressed         difficult situation
# 6                                  NaN      satisfactory situation
# 7                        mostly unfree         noticeable problems
# 8                      moderately free         noticeable problems
# 9                                 free      satisfactory situation
# 10                         mostly free              good situation
# 11                     moderately free      very serious situation
# 12                     moderately free      satisfactory situation
# 13                     moderately free      very serious situation
# 14                       mostly unfree         difficult situation
# 15                       mostly unfree      satisfactory situation
# 16                       mostly unfree         difficult situation
# 17                     moderately free              good situation
# 18                       mostly unfree      satisfactory situation
# 19                       mostly unfree         noticeable problems
# 20                     moderately free         noticeable problems
# 21                           repressed         noticeable problems
# 22                     moderately free         noticeable problems
# 23                     moderately free         noticeable problems
# 24                       mostly unfree         noticeable problems
# 25                     moderately free         difficult situation
# 26                     moderately free         difficult situation
# 27                     moderately free      satisfactory situation
# 28                       mostly unfree         difficult situation
# 29                       mostly unfree      very serious situation
# ..                                 ...                         ...
# 177                        mostly free              good situation
# 178                               free              good situation
# 179                                NaN      very serious situation
# 180                        mostly free      satisfactory situation
# 181                      mostly unfree         difficult situation
# 182                      mostly unfree         noticeable problems
# 183                    moderately free         difficult situation
# 184                          repressed         noticeable problems
# 185                    moderately free         noticeable problems
# 186                                NaN                         NaN
# 187                      mostly unfree      satisfactory situation
# 188                      mostly unfree         noticeable problems
# 189                    moderately free         difficult situation
# 190                          repressed      very serious situation
# 191                                NaN                         NaN
# 192                    moderately free         difficult situation
# 193                      mostly unfree         noticeable problems
# 194                        mostly free         difficult situation
# 195                        mostly free      satisfactory situation
# 196                        mostly free      satisfactory situation
# 197                    moderately free      satisfactory situation
# 198                      mostly unfree      very serious situation
# 199                    moderately free                         NaN
# 200                          repressed         difficult situation
# 201                      mostly unfree      very serious situation
# 202                                NaN         difficult situation
# 203                                NaN                         NaN
# 204                                NaN      very serious situation
# 205                      mostly unfree         difficult situation
# 206                          repressed         difficult situation
#
#     2017 Democracy Index[13]
# 0                        NaN
# 1       authoritarian regime
# 2              hybrid regime
# 3       authoritarian regime
# 4                        NaN
# 5       authoritarian regime
# 6                        NaN
# 7           flawed democracy
# 8              hybrid regime
# 9             full democracy
# 10            full democracy
# 11      authoritarian regime
# 12                       NaN
# 13      authoritarian regime
# 14             hybrid regime
# 15                       NaN
# 16      authoritarian regime
# 17          flawed democracy
# 18                       NaN
# 19             hybrid regime
# 20             hybrid regime
# 21             hybrid regime
# 22             hybrid regime
# 23          flawed democracy
# 24          flawed democracy
# 25                       NaN
# 26          flawed democracy
# 27             hybrid regime
# 28      authoritarian regime
# 29      authoritarian regime
# ..                       ...
# 177           full democracy
# 178           full democracy
# 179     authoritarian regime
# 180         flawed democracy
# 181     authoritarian regime
# 182            hybrid regime
# 183            hybrid regime
# 184     authoritarian regime
# 185                      NaN
# 186                      NaN
# 187         flawed democracy
# 188         flawed democracy
# 189            hybrid regime
# 190     authoritarian regime
# 191                      NaN
# 192            hybrid regime
# 193            hybrid regime
# 194     authoritarian regime
# 195           full democracy
# 196         flawed democracy
# 197           full democracy
# 198     authoritarian regime
# 199                      NaN
# 200     authoritarian regime
# 201     authoritarian regime
# 202                      NaN
# 203                      NaN
# 204     authoritarian regime
# 205            hybrid regime
# 206     authoritarian regime
#
# [207 rows x 5 columns]

# %% [markdown]
# La limpieza requiere estrategia. Lo primero que salta a la vista, son los _footnotes_ que están en los títulos:

# %%
DF.columns
# Out:
# Index(['Country', 'Freedom in the World 2018[10]',
#        '2018 Index of Economic Freedom[11]', '2018 Press Freedom Index[3]',
#        '2017 Democracy Index[13]'],
#       dtype='object')

# %%
# aqui ves que pasa cuando divido cada celda usando el caracter '['
[element.split('[') for element in DF.columns]
# Out:
# [['Country'],
#  ['Freedom in the World 2018', '10]'],
#  ['2018 Index of Economic Freedom', '11]'],
#  ['2018 Press Freedom Index', '3]'],
#  ['2017 Democracy Index', '13]']]

# %%
# Te das cuenta que te puedes quedar con el primer elemento cada vez que partes:
[element.split('[')[0] for element in DF.columns]
# Out:
# ['Country',
#  'Freedom in the World 2018',
#  '2018 Index of Economic Freedom',
#  '2018 Press Freedom Index',
#  '2017 Democracy Index']

# %% [markdown]
# También hay que evitar espacios en blanco:

# %%
outSymbol=' ' 
inSymbol=''
[element.split('[')[0].replace(outSymbol,inSymbol) for element in DF.columns]
# Out:
# ['Country',
#  'FreedomintheWorld2018',
#  '2018IndexofEconomicFreedom',
#  '2018PressFreedomIndex',
#  '2017DemocracyIndex']

# %% [markdown]
# Los números también molestan, pero están en diferentes sitios. Mejor intentemos expresiones regulares:

# %%
import re  # debe estar instalado.

# espacios: \\s+
# one or more number \\d+
# bracket que abre \\[
# bracket que cierra \\]

pattern='\\s+|\\d+|\\[|\\]'
nothing=''

#substituyendo 'pattern' por 'nothing':
[re.sub(pattern,nothing,element) for element in DF.columns]
# Out:
# ['Country',
#  'FreedomintheWorld',
#  'IndexofEconomicFreedom',
#  'PressFreedomIndex',
#  'DemocracyIndex']

# %% [markdown]
# Ya tengo nuevos titulos de columna (headers)!!

# %%
newHeaders=[re.sub(pattern,nothing,element) for element in DF.columns]

# %%
# veamos los cambios:
{old:new for old,new in zip(DF.columns,newHeaders)}
# Out:
# {'Country': 'Country',
#  'Freedom in the World 2018[10]': 'FreedomintheWorld',
#  '2018 Index of Economic Freedom[11]': 'IndexofEconomicFreedom',
#  '2018 Press Freedom Index[3]': 'PressFreedomIndex',
#  '2017 Democracy Index[13]': 'DemocracyIndex'}

# %% [markdown]
# Uso un dict por si hubieses querido cambiar solo algunas columnas:

# %%
changes={old:new for old,new in zip(DF.columns,newHeaders)}
DF.rename(columns=changes,inplace=True)

# %%
# ahora tenemos:
DF
# Out:
#                     Country FreedomintheWorld IndexofEconomicFreedom  \
# 0                  Abkhazia       partly free                    NaN
# 1               Afghanistan          not free          mostly unfree
# 2                   Albania       partly free        moderately free
# 3                   Algeria          not free              repressed
# 4                   Andorra              free                    NaN
# 5                    Angola          not free              repressed
# 6       Antigua and Barbuda              free                    NaN
# 7                 Argentina              free          mostly unfree
# 8                   Armenia       partly free        moderately free
# 9                 Australia              free                   free
# 10                  Austria              free            mostly free
# 11               Azerbaijan          not free        moderately free
# 12                  Bahamas              free        moderately free
# 13                  Bahrain          not free        moderately free
# 14               Bangladesh       partly free          mostly unfree
# 15                 Barbados              free          mostly unfree
# 16                  Belarus          not free          mostly unfree
# 17                  Belgium              free        moderately free
# 18                   Belize              free          mostly unfree
# 19                    Benin              free          mostly unfree
# 20                   Bhutan       partly free        moderately free
# 21                  Bolivia       partly free              repressed
# 22   Bosnia and Herzegovina       partly free        moderately free
# 23                 Botswana              free        moderately free
# 24                   Brazil              free          mostly unfree
# 25                   Brunei          not free        moderately free
# 26                 Bulgaria              free        moderately free
# 27             Burkina Faso       partly free        moderately free
# 28                    Burma       partly free          mostly unfree
# 29                  Burundi          not free          mostly unfree
# ..                      ...               ...                    ...
# 177                  Sweden              free            mostly free
# 178             Switzerland              free                   free
# 179                   Syria          not free                    NaN
# 180                  Taiwan              free            mostly free
# 181              Tajikistan          not free          mostly unfree
# 182                Tanzania       partly free          mostly unfree
# 183                Thailand          not free        moderately free
# 184                    Togo       partly free              repressed
# 185                   Tonga              free        moderately free
# 186            Transnistria          not free                    NaN
# 187     Trinidad and Tobago              free          mostly unfree
# 188                 Tunisia              free          mostly unfree
# 189                  Turkey          not free        moderately free
# 190            Turkmenistan          not free              repressed
# 191                  Tuvalu              free                    NaN
# 192                  Uganda       partly free        moderately free
# 193                 Ukraine       partly free          mostly unfree
# 194    United Arab Emirates          not free            mostly free
# 195          United Kingdom              free            mostly free
# 196           United States              free            mostly free
# 197                 Uruguay              free        moderately free
# 198              Uzbekistan          not free          mostly unfree
# 199                 Vanuatu              free        moderately free
# 200               Venezuela          not free              repressed
# 201                 Vietnam          not free          mostly unfree
# 202               West Bank          not free                    NaN
# 203          Western Sahara          not free                    NaN
# 204                   Yemen          not free                    NaN
# 205                  Zambia       partly free          mostly unfree
# 206                Zimbabwe          not free              repressed
#
#           PressFreedomIndex        DemocracyIndex
# 0                       NaN                   NaN
# 1       difficult situation  authoritarian regime
# 2       noticeable problems         hybrid regime
# 3       difficult situation  authoritarian regime
# 4    satisfactory situation                   NaN
# 5       difficult situation  authoritarian regime
# 6    satisfactory situation                   NaN
# 7       noticeable problems      flawed democracy
# 8       noticeable problems         hybrid regime
# 9    satisfactory situation        full democracy
# 10           good situation        full democracy
# 11   very serious situation  authoritarian regime
# 12   satisfactory situation                   NaN
# 13   very serious situation  authoritarian regime
# 14      difficult situation         hybrid regime
# 15   satisfactory situation                   NaN
# 16      difficult situation  authoritarian regime
# 17           good situation      flawed democracy
# 18   satisfactory situation                   NaN
# 19      noticeable problems         hybrid regime
# 20      noticeable problems         hybrid regime
# 21      noticeable problems         hybrid regime
# 22      noticeable problems         hybrid regime
# 23      noticeable problems      flawed democracy
# 24      noticeable problems      flawed democracy
# 25      difficult situation                   NaN
# 26      difficult situation      flawed democracy
# 27   satisfactory situation         hybrid regime
# 28      difficult situation  authoritarian regime
# 29   very serious situation  authoritarian regime
# ..                      ...                   ...
# 177          good situation        full democracy
# 178          good situation        full democracy
# 179  very serious situation  authoritarian regime
# 180  satisfactory situation      flawed democracy
# 181     difficult situation  authoritarian regime
# 182     noticeable problems         hybrid regime
# 183     difficult situation         hybrid regime
# 184     noticeable problems  authoritarian regime
# 185     noticeable problems                   NaN
# 186                     NaN                   NaN
# 187  satisfactory situation      flawed democracy
# 188     noticeable problems      flawed democracy
# 189     difficult situation         hybrid regime
# 190  very serious situation  authoritarian regime
# 191                     NaN                   NaN
# 192     difficult situation         hybrid regime
# 193     noticeable problems         hybrid regime
# 194     difficult situation  authoritarian regime
# 195  satisfactory situation        full democracy
# 196  satisfactory situation      flawed democracy
# 197  satisfactory situation        full democracy
# 198  very serious situation  authoritarian regime
# 199                     NaN                   NaN
# 200     difficult situation  authoritarian regime
# 201  very serious situation  authoritarian regime
# 202     difficult situation                   NaN
# 203                     NaN                   NaN
# 204  very serious situation  authoritarian regime
# 205     difficult situation         hybrid regime
# 206     difficult situation  authoritarian regime
#
# [207 rows x 5 columns]

# %% [markdown]
# Las columnas son categorías, veamos si todas se han escrito de la manera correcta:

# %%
DF.FreedomintheWorld.value_counts()
# Out:
# free           89
# partly free    62
# not free       55
# Name: FreedomintheWorld, dtype: int64

# %%
DF.IndexofEconomicFreedom.value_counts()
# Out:
# mostly unfree      63
# moderately free    62
# mostly free        28
# repressed          21
# free                6
# Name: IndexofEconomicFreedom, dtype: int64

# %%
DF.PressFreedomIndex.value_counts()
# Out:
# noticeable problems       63
# difficult situation       50
# satisfactory situation    37
# very serious situation    22
# good situation            17
# Name: PressFreedomIndex, dtype: int64

# %%
DF.DemocracyIndex.value_counts()
# Out:
# flawed democracy        57
# authoritarian regime    52
# hybrid regime           39
# full democracy          19
# Name: DemocracyIndex, dtype: int64

# %% [markdown]
# Pues hasta aquí está conforme. Veamos otro caso.

# %%
idhCol="https://www.datosmacro.com/idh/colombia" 
iframe = '<iframe src=' + idhCol + ' width=700 height=350></iframe>'
IPython.display.HTML(iframe)
# Out:
# <iframe src=https://www.datosmacro.com/idh/colombia width=700 height=350></iframe>

# %%
import pandas as pd

webTable=pd.read_html(idhCol,header=0,flavor='bs4',attrs={'id': 'tb0',})

# %%
len(webTable)
# Out:
# 1

# %%
idhColT=webTable[0]
idhColT
# Out:
#     Fecha  IDH Ranking IDH
# 0    2015  727         95º
# 1    2014  724         97º
# 2    2013  720         98º
# 3    2012  712         98º
# 4    2011  707         98º
# 5    2010  700         97º
# 6    2009  695         98º
# 7    2008  691         89º
# 8    2007  683         99º
# 9    2006  675         99º
# 10   2005  669         92º
# 11   2004  658         95º
# 12   2003  658         94º
# 13   2002  659         91º
# 14   2001  656         89º
# 15   2000  653         78º
# 16   1999  650         77º
# 17   1998  650         75º
# 18   1997  643         76º
# 19   1996  635         78º
# 20   1995  626         79º
# 21   1994  620         77º
# 22   1993  613         78º
# 23   1992  606         77º
# 24   1991  595         82º
# 25   1990  592         80º

# %% [markdown]
# El problema es que se borraron los decimales. Como se ve en la web, estos tenían una coma en vez de un punto. A esta altura podemos eliminarlo, o buscar si durante el proceso de colección se puede mejorar esto; dale una mirada a la función:

# %%
# ?pd.read_html

# %% [markdown]
# Siguiendo las instrucciones escibimos:

# %%
idhColT=pd.read_html(idhCol,header=0,flavor='bs4',attrs={'id': 'tb0',},
                      thousands=None, decimal=',')[0]
idhColT
# Out:
#     Fecha    IDH Ranking IDH
# 0    2015  0.727         95º
# 1    2014  0.724         97º
# 2    2013  0.720         98º
# 3    2012  0.712         98º
# 4    2011  0.707         98º
# 5    2010  0.700         97º
# 6    2009  0.695         98º
# 7    2008  0.691         89º
# 8    2007  0.683         99º
# 9    2006  0.675         99º
# 10   2005  0.669         92º
# 11   2004  0.658         95º
# 12   2003  0.658         94º
# 13   2002  0.659         91º
# 14   2001  0.656         89º
# 15   2000  0.653         78º
# 16   1999  0.650         77º
# 17   1998  0.650         75º
# 18   1997  0.643         76º
# 19   1996  0.635         78º
# 20   1995  0.626         79º
# 21   1994  0.620         77º
# 22   1993  0.613         78º
# 23   1992  0.606         77º
# 24   1991  0.595         82º
# 25   1990  0.592         80º

# %% [markdown]
# El ranking no es un numero, pues el símbolo ordinal lo evita, eliminemoslo:

# %%
idhColT.loc[:,'Ranking IDH']=idhColT.loc[:,'Ranking IDH'].str.replace('º',"")
idhColT
# Out:
#     Fecha    IDH Ranking IDH
# 0    2015  0.727          95
# 1    2014  0.724          97
# 2    2013  0.720          98
# 3    2012  0.712          98
# 4    2011  0.707          98
# 5    2010  0.700          97
# 6    2009  0.695          98
# 7    2008  0.691          89
# 8    2007  0.683          99
# 9    2006  0.675          99
# 10   2005  0.669          92
# 11   2004  0.658          95
# 12   2003  0.658          94
# 13   2002  0.659          91
# 14   2001  0.656          89
# 15   2000  0.653          78
# 16   1999  0.650          77
# 17   1998  0.650          75
# 18   1997  0.643          76
# 19   1996  0.635          78
# 20   1995  0.626          79
# 21   1994  0.620          77
# 22   1993  0.613          78
# 23   1992  0.606          77
# 24   1991  0.595          82
# 25   1990  0.592          80

# %% [markdown]
# Traigamos una nueva tabla:

# %%
idhCol2='https://es.wikipedia.org/wiki/Anexo:Departamentos_de_Colombia_por_IDH'
iframe = '<iframe src=' + idhCol2 + ' width=700 height=350></iframe>'
IPython.display.HTML(iframe)
# Out:
# <iframe src=https://es.wikipedia.org/wiki/Anexo:Departamentos_de_Colombia_por_IDH width=700 height=350></iframe>

# %% [markdown]
# Aparentemente sabemos qué hacer:

# %%
idhColT2=pd.read_html(idhCol2,header=0,flavor='bs4',attrs={'class': 'sortable',},
                       thousands=' ', decimal=',')[0]
idhColT2
# Out:
#                       Entidad    IDH Población[2]​  \
# 0                      Bogotá  0.904     7 674 366
# 1                   Santander  0.879     2 340 988
# 2                    Casanare  0.867       344 027
# 3             Valle del Cauca  0.861     4 520 166
# 4                   Antioquia  0.849     6 299 886
# 5                      Boyacá  0.842       1405122
# 6                   Risaralda  0.839       941 283
# 7                Cundinamarca  0.837     2 598 245
# 8                   Atlántico  0.835     2 403 027
# 9                  San Andrés  0.834        75 167
# 10                    Quindío  0.832       558 934
# 11                     Caldas  0.828       984 128
# 12                    Bolívar  0.823     2 049 083
# 13                       Meta  0.822       924 843
# 14                      Cesar  0.810     1 004 064
# 15                      Huila  0.807     1 126 314
# 16                     Arauca  0.804       256 527
# 17                     Tolima  0.804     1 400 203
# 18                    Córdoba  0.798     1 658 090
# 19         Norte de Santander  0.796     1 332 335
# 20                  Magdalena  0.785     1 235 425
# 21                      Cauca  0.782     1 354 744
# 22                      Sucre  0.775       834 927
# 23                     Nariño  0.773     1 701 840
# 24  Región Amazónica[nota 2]​  0.768            --
# 25                   Putumayo  0.759       337 054
# 26                    Caquetá  0.752       465 477
# 27                      Chocó  0.731       490 327
# 28                 La Guajira  0.691       902 386
# 29                   Colombia  0.840    47 121 089
#
#    País Comparable[3]​ [nota 1]​
# 0                República Checa
# 1                        Hungría
# 2                      Argentina
# 3                        Bahamas
# 4                         Brasil
# 5                       Bulgaria
# 6         San Cristóbal y Nieves
# 7                        Rumania
# 8                     Montenegro
# 9                     Montenegro
# 10                       Malasia
# 11                        Serbia
# 12                   Santa Lucía
# 13                   Santa Lucía
# 14                          Peru
# 15                          Peru
# 16                    Kazajistán
# 17                    Kazajistán
# 18                       Armenia
# 19                       Ucrania
# 20                     Tailandia
# 21                          Irán
# 22                         China
# 23                         China
# 24                         Tonga
# 25                     Sri Lanka
# 26                     Filipinas
# 27                       Bolivia
# 28                    Tayikistán
# 29                            --

# %% [markdown]
# Aparentemente, sólo Boyacá tenía espacios en blanco.
#
# En este caso, el primer problema es que los miles marcados con _espacios_ no desaparecieron. Eso se debe a que en el html están señalados como **& nbsp;**. De ahi que:

# %%
idhColT2=pd.read_html(idhCol2,header=0,flavor='bs4',attrs={'class': 'sortable',},
                       thousands='\xa0', decimal=',')[0]
idhColT2
# Out:
#                       Entidad    IDH Población[2]​  \
# 0                      Bogotá  0.904       7674366
# 1                   Santander  0.879       2340988
# 2                    Casanare  0.867        344027
# 3             Valle del Cauca  0.861       4520166
# 4                   Antioquia  0.849       6299886
# 5                      Boyacá  0.842     1 405 122
# 6                   Risaralda  0.839        941283
# 7                Cundinamarca  0.837       2598245
# 8                   Atlántico  0.835       2403027
# 9                  San Andrés  0.834         75167
# 10                    Quindío  0.832        558934
# 11                     Caldas  0.828        984128
# 12                    Bolívar  0.823       2049083
# 13                       Meta  0.822        924843
# 14                      Cesar  0.810       1004064
# 15                      Huila  0.807       1126314
# 16                     Arauca  0.804        256527
# 17                     Tolima  0.804       1400203
# 18                    Córdoba  0.798       1658090
# 19         Norte de Santander  0.796       1332335
# 20                  Magdalena  0.785       1235425
# 21                      Cauca  0.782       1354744
# 22                      Sucre  0.775        834927
# 23                     Nariño  0.773       1701840
# 24  Región Amazónica[nota 2]​  0.768            --
# 25                   Putumayo  0.759        337054
# 26                    Caquetá  0.752        465477
# 27                      Chocó  0.731        490327
# 28                 La Guajira  0.691        902386
# 29                   Colombia  0.840      47121089
#
#    País Comparable[3]​ [nota 1]​
# 0                República Checa
# 1                        Hungría
# 2                      Argentina
# 3                        Bahamas
# 4                         Brasil
# 5                       Bulgaria
# 6         San Cristóbal y Nieves
# 7                        Rumania
# 8                     Montenegro
# 9                     Montenegro
# 10                       Malasia
# 11                        Serbia
# 12                   Santa Lucía
# 13                   Santa Lucía
# 14                          Peru
# 15                          Peru
# 16                    Kazajistán
# 17                    Kazajistán
# 18                       Armenia
# 19                       Ucrania
# 20                     Tailandia
# 21                          Irán
# 22                         China
# 23                         China
# 24                         Tonga
# 25                     Sri Lanka
# 26                     Filipinas
# 27                       Bolivia
# 28                    Tayikistán
# 29                            --

# %% [markdown]
# Pues, Boyacá es ahora el problema. Eso lo resolveremos fuera de la llamada:

# %%
idhColT2.iloc[:,2]=idhColT2.iloc[:,2].str.replace("\s","")
idhColT2
# Out:
#                       Entidad    IDH Población[2]​  \
# 0                      Bogotá  0.904       7674366
# 1                   Santander  0.879       2340988
# 2                    Casanare  0.867        344027
# 3             Valle del Cauca  0.861       4520166
# 4                   Antioquia  0.849       6299886
# 5                      Boyacá  0.842       1405122
# 6                   Risaralda  0.839        941283
# 7                Cundinamarca  0.837       2598245
# 8                   Atlántico  0.835       2403027
# 9                  San Andrés  0.834         75167
# 10                    Quindío  0.832        558934
# 11                     Caldas  0.828        984128
# 12                    Bolívar  0.823       2049083
# 13                       Meta  0.822        924843
# 14                      Cesar  0.810       1004064
# 15                      Huila  0.807       1126314
# 16                     Arauca  0.804        256527
# 17                     Tolima  0.804       1400203
# 18                    Córdoba  0.798       1658090
# 19         Norte de Santander  0.796       1332335
# 20                  Magdalena  0.785       1235425
# 21                      Cauca  0.782       1354744
# 22                      Sucre  0.775        834927
# 23                     Nariño  0.773       1701840
# 24  Región Amazónica[nota 2]​  0.768            --
# 25                   Putumayo  0.759        337054
# 26                    Caquetá  0.752        465477
# 27                      Chocó  0.731        490327
# 28                 La Guajira  0.691        902386
# 29                   Colombia  0.840      47121089
#
#    País Comparable[3]​ [nota 1]​
# 0                República Checa
# 1                        Hungría
# 2                      Argentina
# 3                        Bahamas
# 4                         Brasil
# 5                       Bulgaria
# 6         San Cristóbal y Nieves
# 7                        Rumania
# 8                     Montenegro
# 9                     Montenegro
# 10                       Malasia
# 11                        Serbia
# 12                   Santa Lucía
# 13                   Santa Lucía
# 14                          Peru
# 15                          Peru
# 16                    Kazajistán
# 17                    Kazajistán
# 18                       Armenia
# 19                       Ucrania
# 20                     Tailandia
# 21                          Irán
# 22                         China
# 23                         China
# 24                         Tonga
# 25                     Sri Lanka
# 26                     Filipinas
# 27                       Bolivia
# 28                    Tayikistán
# 29                            --

# %% [markdown]
# Los nombres de columnas necesitan tratamiento, podríamos usar lo que ya vimos:

# %%
[re.sub(pattern,nothing,element) for element in idhColT2.columns]
# Out:
# ['Entidad', 'IDH', 'Población\u200b', 'PaísComparable\u200bnota\u200b']

# %% [markdown]
# O mejorar el patrón:

# %%
pattern2='\\s+|\\d+|\\[|\\]|\\u200b'
[re.sub(pattern2,nothing,element) for element in idhColT2.columns]
# Out:
# ['Entidad', 'IDH', 'Población', 'PaísComparablenota']

# %% [markdown]
# Pero esta vez, hay _footnotes_ con texto, cuando antes sólo tenía números, de ahi que jueguemos simple:

# %%
[element.split('[')[0].replace(" ","") for element in idhColT2.columns]
# Out:
# ['Entidad', 'IDH', 'Población', 'PaísComparable']

# %% [markdown]
# Cambiemos con esto los _headers_:

# %%
idhColT2.columns=[element.split('[')[0].replace(" ","") for element in idhColT2.columns]
idhColT2
# Out:
#                       Entidad    IDH Población          PaísComparable
# 0                      Bogotá  0.904   7674366         República Checa
# 1                   Santander  0.879   2340988                 Hungría
# 2                    Casanare  0.867    344027               Argentina
# 3             Valle del Cauca  0.861   4520166                 Bahamas
# 4                   Antioquia  0.849   6299886                  Brasil
# 5                      Boyacá  0.842   1405122                Bulgaria
# 6                   Risaralda  0.839    941283  San Cristóbal y Nieves
# 7                Cundinamarca  0.837   2598245                 Rumania
# 8                   Atlántico  0.835   2403027              Montenegro
# 9                  San Andrés  0.834     75167              Montenegro
# 10                    Quindío  0.832    558934                 Malasia
# 11                     Caldas  0.828    984128                  Serbia
# 12                    Bolívar  0.823   2049083             Santa Lucía
# 13                       Meta  0.822    924843             Santa Lucía
# 14                      Cesar  0.810   1004064                    Peru
# 15                      Huila  0.807   1126314                    Peru
# 16                     Arauca  0.804    256527              Kazajistán
# 17                     Tolima  0.804   1400203              Kazajistán
# 18                    Córdoba  0.798   1658090                 Armenia
# 19         Norte de Santander  0.796   1332335                 Ucrania
# 20                  Magdalena  0.785   1235425               Tailandia
# 21                      Cauca  0.782   1354744                    Irán
# 22                      Sucre  0.775    834927                   China
# 23                     Nariño  0.773   1701840                   China
# 24  Región Amazónica[nota 2]​  0.768        --                   Tonga
# 25                   Putumayo  0.759    337054               Sri Lanka
# 26                    Caquetá  0.752    465477               Filipinas
# 27                      Chocó  0.731    490327                 Bolivia
# 28                 La Guajira  0.691    902386              Tayikistán
# 29                   Colombia  0.840  47121089                      --

# %% [markdown]
# Sucede algo similar con los contenidos de las columnas (vease 'Región Amazónica'). De ahí que:

# %%
idhColT2.Entidad=[element.split('[')[0] for element in idhColT2.Entidad]
idhColT2
# Out:
#                Entidad    IDH Población          PaísComparable
# 0               Bogotá  0.904   7674366         República Checa
# 1            Santander  0.879   2340988                 Hungría
# 2             Casanare  0.867    344027               Argentina
# 3      Valle del Cauca  0.861   4520166                 Bahamas
# 4            Antioquia  0.849   6299886                  Brasil
# 5               Boyacá  0.842   1405122                Bulgaria
# 6            Risaralda  0.839    941283  San Cristóbal y Nieves
# 7         Cundinamarca  0.837   2598245                 Rumania
# 8            Atlántico  0.835   2403027              Montenegro
# 9           San Andrés  0.834     75167              Montenegro
# 10             Quindío  0.832    558934                 Malasia
# 11              Caldas  0.828    984128                  Serbia
# 12             Bolívar  0.823   2049083             Santa Lucía
# 13                Meta  0.822    924843             Santa Lucía
# 14               Cesar  0.810   1004064                    Peru
# 15               Huila  0.807   1126314                    Peru
# 16              Arauca  0.804    256527              Kazajistán
# 17              Tolima  0.804   1400203              Kazajistán
# 18             Córdoba  0.798   1658090                 Armenia
# 19  Norte de Santander  0.796   1332335                 Ucrania
# 20           Magdalena  0.785   1235425               Tailandia
# 21               Cauca  0.782   1354744                    Irán
# 22               Sucre  0.775    834927                   China
# 23              Nariño  0.773   1701840                   China
# 24    Región Amazónica  0.768        --                   Tonga
# 25            Putumayo  0.759    337054               Sri Lanka
# 26             Caquetá  0.752    465477               Filipinas
# 27               Chocó  0.731    490327                 Bolivia
# 28          La Guajira  0.691    902386              Tayikistán
# 29            Colombia  0.840  47121089                      --

# %% [markdown]
# Ten en cuenta que la nota que acabamos de eliminar decía: _'Se refiere los departamentos de Amazonas, Guainia, Guaviare, Vaupés y Vichada.'_ Una alternativa, que haremos aquí es crear esas filas:

# %%
# nombres nuevos
newRows=['Amazonas', 'Guainia', 'Guaviare', 'Vaupés', 'Vichada']

# %%
#Valor de Region Amazonica:
idhColT2[idhColT2.Entidad=='Región Amazónica']
# Out:
#              Entidad    IDH Población PaísComparable
# 24  Región Amazónica  0.768        --          Tonga

# %%
#Valor de Region Amazonica como lista:
idhColT2[idhColT2.Entidad=='Región Amazónica'].values.tolist()[0]
# Out:
# ['Región Amazónica', 0.768, '--', 'Tonga']

# %%
#Valor de Region Amazonica como lista, sin elemento 1:
idhColT2[idhColT2.Entidad=='Región Amazónica'].values.tolist()[0][1:]
# Out:
# [0.768, '--', 'Tonga']

# %%
info=idhColT2[idhColT2.Entidad=='Región Amazónica'].values.tolist()[0][1:]

# %%
# creando filas nuevas como listas:

[[row] + info for row in newRows]
# Out:
# [['Amazonas', 0.768, '--', 'Tonga'],
#  ['Guainia', 0.768, '--', 'Tonga'],
#  ['Guaviare', 0.768, '--', 'Tonga'],
#  ['Vaupés', 0.768, '--', 'Tonga'],
#  ['Vichada', 0.768, '--', 'Tonga']]

# %%
newData = pd.DataFrame([[row] + info for row in newRows], columns=idhColT2.columns)
idhColT2.append(newData,ignore_index=True)
# Out:
#                Entidad    IDH Población          PaísComparable
# 0               Bogotá  0.904   7674366         República Checa
# 1            Santander  0.879   2340988                 Hungría
# 2             Casanare  0.867    344027               Argentina
# 3      Valle del Cauca  0.861   4520166                 Bahamas
# 4            Antioquia  0.849   6299886                  Brasil
# 5               Boyacá  0.842   1405122                Bulgaria
# 6            Risaralda  0.839    941283  San Cristóbal y Nieves
# 7         Cundinamarca  0.837   2598245                 Rumania
# 8            Atlántico  0.835   2403027              Montenegro
# 9           San Andrés  0.834     75167              Montenegro
# 10             Quindío  0.832    558934                 Malasia
# 11              Caldas  0.828    984128                  Serbia
# 12             Bolívar  0.823   2049083             Santa Lucía
# 13                Meta  0.822    924843             Santa Lucía
# 14               Cesar  0.810   1004064                    Peru
# 15               Huila  0.807   1126314                    Peru
# 16              Arauca  0.804    256527              Kazajistán
# 17              Tolima  0.804   1400203              Kazajistán
# 18             Córdoba  0.798   1658090                 Armenia
# 19  Norte de Santander  0.796   1332335                 Ucrania
# 20           Magdalena  0.785   1235425               Tailandia
# 21               Cauca  0.782   1354744                    Irán
# 22               Sucre  0.775    834927                   China
# 23              Nariño  0.773   1701840                   China
# 24    Región Amazónica  0.768        --                   Tonga
# 25            Putumayo  0.759    337054               Sri Lanka
# 26             Caquetá  0.752    465477               Filipinas
# 27               Chocó  0.731    490327                 Bolivia
# 28          La Guajira  0.691    902386              Tayikistán
# 29            Colombia  0.840  47121089                      --
# 30            Amazonas  0.768        --                   Tonga
# 31             Guainia  0.768        --                   Tonga
# 32            Guaviare  0.768        --                   Tonga
# 33              Vaupés  0.768        --                   Tonga
# 34             Vichada  0.768        --                   Tonga

# %%
# Ya que estamos satisfechos:
idhColT2=idhColT2.append(newData,ignore_index=True)

# %% [markdown]
# En el DF sobran ya tres filas, la que hemos desagregado, 'Bogota' y 'Colombia':

# %%
idhColT2[idhColT2.Entidad.isin (['Región Amazónica','Colombia','Bogotá'])]
# Out:
#              Entidad    IDH Población   PaísComparable
# 0             Bogotá  0.904   7674366  República Checa
# 24  Región Amazónica  0.768        --            Tonga
# 29          Colombia  0.840  47121089               --

# %%
#eliminando
idhColT2.drop([0,24,29],inplace=True)
idhColT2.reset_index(drop=True,inplace=True)

# %% [markdown]
# Es importante darnos cuenta que hay símbolos _no apropiados_ para representar valores faltantes (i.e.'--'). Eso es preocupante, en particular para los numéricos. Juntemos ambas columnas para buscar inapropiados:

# %%
numericos=list(idhColT2.IDH)
numericos.extend(list(idhColT2.Población))

# %%
numericos
# Out:
# [0.879,
#  0.867,
#  0.861,
#  0.8490000000000001,
#  0.8420000000000001,
#  0.8390000000000001,
#  0.8370000000000001,
#  0.835,
#  0.8340000000000001,
#  0.8320000000000001,
#  0.828,
#  0.823,
#  0.8220000000000001,
#  0.81,
#  0.807,
#  0.804,
#  0.804,
#  0.7979999999999999,
#  0.7959999999999999,
#  0.785,
#  0.782,
#  0.775,
#  0.773,
#  0.759,
#  0.752,
#  0.731,
#  0.691,
#  0.768,
#  0.768,
#  0.768,
#  0.768,
#  0.768,
#  '2340988',
#  '344027',
#  '4520166',
#  '6299886',
#  '1405122',
#  '941283',
#  '2598245',
#  '2403027',
#  '75167',
#  '558934',
#  '984128',
#  '2049083',
#  '924843',
#  '1004064',
#  '1126314',
#  '256527',
#  '1400203',
#  '1658090',
#  '1332335',
#  '1235425',
#  '1354744',
#  '834927',
#  '1701840',
#  '337054',
#  '465477',
#  '490327',
#  '902386',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--']

# %% [markdown]
# Vemos que varios numeros está como texto, lo que por ahora no es problema. La idea es encontrar aquello que están entre los números y no lo son:

# %%
for n in numericos:
    float(n)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-257-1072b9d27869> in <module>()
#       1 for n in numericos:
# ----> 2     float(n)
#
# ValueError: could not convert string to float: '--'

# %% [markdown]
# Hemos encontrado un simbolo que no se puede convertir a _float_. POdría haber otros, pero ya sabemos qué error arroja.
#
# De ahí que:

# %%
inapropiados=[]
for n in numericos:
    try:
        float(n)
    except ValueError:
        if not n in inapropiados: # evitar duplicados
            inapropiados.append(n)

# %%
# aqui están
inapropiados
# Out:
# ['--']

# %% [markdown]
# Sólo había un símbolo (ya lo sabíamos), pero el código sirve para más de uno.
#
# Lo que nos queda es reemplazar ese valor por 'None':

# %%
idhColT2.replace(inapropiados,value=[None]*len(inapropiados)) # se necesita la misma cantidad de 'None'
# Out:
#                Entidad    IDH Población          PaísComparable
# 0            Santander  0.879   2340988                 Hungría
# 1             Casanare  0.867    344027               Argentina
# 2      Valle del Cauca  0.861   4520166                 Bahamas
# 3            Antioquia  0.849   6299886                  Brasil
# 4               Boyacá  0.842   1405122                Bulgaria
# 5            Risaralda  0.839    941283  San Cristóbal y Nieves
# 6         Cundinamarca  0.837   2598245                 Rumania
# 7            Atlántico  0.835   2403027              Montenegro
# 8           San Andrés  0.834     75167              Montenegro
# 9              Quindío  0.832    558934                 Malasia
# 10              Caldas  0.828    984128                  Serbia
# 11             Bolívar  0.823   2049083             Santa Lucía
# 12                Meta  0.822    924843             Santa Lucía
# 13               Cesar  0.810   1004064                    Peru
# 14               Huila  0.807   1126314                    Peru
# 15              Arauca  0.804    256527              Kazajistán
# 16              Tolima  0.804   1400203              Kazajistán
# 17             Córdoba  0.798   1658090                 Armenia
# 18  Norte de Santander  0.796   1332335                 Ucrania
# 19           Magdalena  0.785   1235425               Tailandia
# 20               Cauca  0.782   1354744                    Irán
# 21               Sucre  0.775    834927                   China
# 22              Nariño  0.773   1701840                   China
# 23            Putumayo  0.759    337054               Sri Lanka
# 24             Caquetá  0.752    465477               Filipinas
# 25               Chocó  0.731    490327                 Bolivia
# 26          La Guajira  0.691    902386              Tayikistán
# 27            Amazonas  0.768      None                   Tonga
# 28             Guainia  0.768      None                   Tonga
# 29            Guaviare  0.768      None                   Tonga
# 30              Vaupés  0.768      None                   Tonga
# 31             Vichada  0.768      None                   Tonga

# %%
idhColT2.replace(inapropiados,value=[None]*len(inapropiados),inplace=True)
